# %% [markdown]
# <a href="https://colab.research.google.com/github/Mansingh7697/Python/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Variables:
# It is container for storing values like numbers, string, list, set, tuples, etc.
# Python is Dynamically typed language>> no need to declare the type of variable.
#
# Rules to define Variables:
# 1. letters a-z, A-Z, and numbers 0-9.
# 2. We can not use any special character except '_'.
# 3. We can not start a variable name with number.
# 4. Case sensitive
# 5. We can not use reserved words as a variable >> (there are 33 reserved words. )
# 6. There is should not be space in between.
# ```

# %% [markdown]
# Print Statements:

# %%
a = 10
b = 20
print(a)
print(b)
print('Addition of a and b is :', a+b)
print('Addition of', a , 'and', b ,'is :', a+b)

print(f"Addition of {a} and {b} is :{a+b}")

print('Addition of {} and {} is {}'.format(a,b,a+b))

print('Value of a=%d and b=%f'%(a,b))

# %% [markdown]
# Data Types:
#
# Numeric : int, float, complex
#
# Text : str
#
# Sequence : list, tuple, range
#
# Mapping : dict
#
# SetDT : set, frozenset
#
# boolean : bool(true and false)

# %%
# Numeric Data Types

n = 24
type(n)

# %%
n = -9.4
type(n)

# %%
x = 1+5j
type(x)

# %% [markdown]
# Python Type Casting : Do it yourself.

# %% [markdown]
# Strings:
# String is a collection of characters/ special characters/numbers etc which is surrounded or enclosed by single, double or triple quote.

# %%
string = "Data Science"
print(string)

# %%
text1 = 'Python \'and\' Data Science'
print(text1)

# %%
string2 = """ I am learning Python
And I am happily learning this."""
print(string2)

# %% [markdown]
# String Indexing:
#
# Indexing : It is simply giving us a position of perticular character in our string
# There are two types of indexing:
# 1. positive Indexing
# 2. Negative Indexing

# %%
string = 'python'

                     P  y  t  h  o  n
Positive Indexing :  0  1  2  3  4  5
Negative Indexing : -6 -5 -4 -3 -2 -1

# %%
string[2]

# %%
string[-3]

# %%
length = len(string)
length

# %% [markdown]
# String Slicing: We can cut or we can have any part of string.
#
# string[start index : end index]
#
# end index is excluded.

# %%
str1 ='Python'
str1[0:2]    # 0 1 (2nd index is excluded)

# %% [markdown]
# string[start index : end index : step size]
#
# step size is by default 1.

# %%
str2 = 'Data Science'
len(str2)
str2[0:13]
str2[0:13:1]
str2[0:13:2]

# %%
print('Original string is:', str2[::1])

# %%
print('Reversed string is:', str3[::-1])

# %%
str2[::-1]

# %% [markdown]
# String is text data type.
#
# Strings are immutable.

# %%
str1 = '123'
print(type(str1))
str2 = '456'
str1 +" "+str2

# %%
str1 = 123
str2 = 456
str1 + str2

# %% [markdown]
# ## String Functions
#
# 1. Capitalize()
# 2. upper()
# 3. lower()
# 4. title()
# 5. lstrip()
# 6. rstrip()
# 7. strip()
# 8. swapcase()
# 9. replace()
# 10. count()
# 11. index()
# 12. find()
# 13. split()
# 14. join()
# 15. startswith()
# 16. endswith()
# 17. isalnum()
# 18. isalpha()
# 19. isdecimal()
# 20. isdigit()

# %%
str3 = 'python is dynamically typed language'
str3.capitalize()
str3[0:6].lower()
str4 = str3.upper()
str3.lower()
str3.title()

# %%
string = "    Artificial Intelligence     "
string.lstrip()
string.rstrip()
string.strip()

# %%
str3.swapcase()

# %%
# string.replace( old_str, new_str)
str1 = 'Data Science'
str1.replace('a', '#')

# %%
# string.count(substring)
# string.count(substring, start_index, end_index)

text = '''Data Science Is An Interdisciplinary Field That Uses Scientific Methods, Processes,
Algorithms And Systems To Extract Knowledge And Insights From Noisy,
Structured And Unstructured Data, And Apply Knowledge From Data Across A Broad Range Of Application Domains.'''

text.count('And')
text.count('Data', 0, 250)

# %%
# string.index(substring, start_index, end_index)    ## It gives the index of substring

str1= """ Data science is an interdisciplinary field that uses scientific methods, processes,
 algorithms and systems to extract knowledge and insights
 from noisy, structured and unstructured data, and apply knowledge from data across a broad
 range of application domains."""

str1.index('from')
str1.index('data', 0, 250)
str1.find('data', 0, 250)

# %%
string = 'Python is freeware and open source, it does have extensive libraries'
print(string.split())
string.split('is')

# %%
string1 = ''.join(string)
string3

# %%
string2 = ' '.join(string)
string2

# %%
string3 = '_'.join(string)
string3

# %%
string = 'Python is freeware and open source, it does have extensive libraries'
string.startswith('python')

# %%
str1='www.google.com'
str1.endswith('.com')

# %%
string = 'python'
string.isalpha()

# %%
string = 'python_Data_science'
string.isalnum()

# %%
string= '123'
string.isdecimal()

# %%
string = 123
string.isdecimal()

# %% [markdown]
# ## Try yourself
# 21. islower()
# 22. istitle()
# 23. isupper()
# 24. isspace()
# 25. zfill()
# 26. center()
# 27. isdigit()

# %% [markdown]
# # Operators:
# ## Arithmatic Operators
# ### + >> Addition
# ### - >> Substraction
# ### * >> Multiplication
# ### / >> Division
# ### % >> mod >> gives reminder
# ### // >> Floor division
# ### ** >> power
#
#
# ## Assignment Operators
# ### += >> a+=1 >> a = a+1
# ### -= >> a-=1 >> a=a-1
# ### *=
# ### /=
# ### //=
# ### **=
# ### %=
#
#
# ## Logical Opeartors
#
# ### and
# ### or
# ### not

# %% [markdown]
# # Membership Operator
# ## in
# ## not in

# %%
list1 =[ 1,4,7,9,6,3]
4 in list1

# %%
2 in list1

# %% [markdown]
# # Comparison Operators
#
# ## == >> equal to
# ## != >> Not equal to
# ## >  >> Greater than
# ## <  >> Less than
# ## >= >> Geater than or equal to
# ## <= >> Less than or equal to
#
#
# # Identity Operator
#
# ## is
# ## is not

# %%
# If - Else Condition

if condition: #whether it is true / false.
    statement/ block of code

*****************************************************

if condition: # whether it is true / false.
    statement1/Block of code
else:
    statement2/block of code


*****************************************************

if condition1: # whether it is true / false.
    statement1/block of code
elif condition2:
    statement2
elif condition3:
    statement3
else:
    statement4

*****************************************************

if >> else >> elif>>..... It will give a syntax error.

# %%
a = int(input('Enter the number: ')) ## user can enter only integer

a = float(input('Enter the number: ')) ## user can enter only float

a = eval(input('Enter the number: ')) ## user can enter either integer / float.

# %%
s = input("Enter your name: ")
print(f"Welcome {s}")
type(s)

# %% [markdown]
# # Range()
#
# range(start_index, end_index, step_size)  # end index is excluded

# %%
range(1,10)

# %%
list(range(1,10))

# %%
list(range(10))

# %%
for i in range(65,91):
    print(chr(i))
